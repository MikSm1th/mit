# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy as sym
import math

# %%
import matplotlib as mpl
import mpl_toolkits.axisartist as AxisArtist
import matplotlib.ticker as ticker
import grids as g

# %% [raw]
# plt.style.use('seaborn')

# %%
x = np.arange(-7,-2, 1)
y = [3*((i+5)**2)-1 for i in x]
x,y
# Out:
# (array([-7, -6, -5, -4, -3]), [11, 2, -1, 2, 11])

# %%
g.simple_grid_10x10(x,y)

# %%
def popsize(t):
    return 2800/(1 + 6*np.exp(-0.3*t))

# %%
popsize(0)
# Out:
# 400.0

# %%
popsize(7)
# Out:
# 1614.0760626416231

# %%
def slope(x1,y1,x2,y2):
    return (y2-y1)/(x2-x1)

# %%
slope(2,4,-6,-6)
# Out:
# 1.25

# %%
plt.rcParams['figure.facecolor'] = 'grey'
plt.rcParams['figure.figsize'] = (12,6)

# %%
x = np.arange(-3.3, 12 , 0.1)
x_ticks = np.arange(-np.pi, 4*np.pi, (np.pi/4))
cos_y = np.cos(x)
sin_y = np.sin(x)
tan_y = np.tan(x)
plt.plot(x,cos_y)
plt.plot(x,sin_y)
#plt.plot(x,tan_y)
plt.xticks(x_ticks)
plt.grid(True, which='both')
plt.axhline(y=0, color='black', linestyle=':')
plt.axvline(x=0, color='black', linestyle=':')
plt.show()

# %%
x_sym = [0, sym.pi/2.0, sym.pi, (3*sym.pi)/2.0, 2*sym.pi]

# %%
# ?pd.DataFrame
# Out:
# Init signature:
# pd.DataFrame(
#     data=None,
#     index: 'Optional[Axes]' = None,
#     columns: 'Optional[Axes]' = None,
#     dtype: 'Optional[Dtype]' = None,
#     copy: 'bool' = False,
# )
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order.
#
#     .. versionchanged:: 0.25.0
#        If data is a list of dicts, column order follows insertion-order.
#
# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
df = pd.DataFrame(x_sym, columns=['x'])
df
# Out:
#         x
# 0       0
# 1  0.5*pi
# 2      pi
# 3  1.5*pi
# 4    2*pi

# %%
x = [0, np.pi/2.0, np.pi, (3*np.pi)/2.0, 2*np.pi]
y = [round(np.cos(i),2) for i in x]
y_two_thirds = [round((2/3)*np.cos(i),2) for i in x]
df['y'] = y
df['2/3y'] = y_two_thirds
df
# Out:
#         x    y  2/3y
# 0       0  1.0  0.67
# 1  0.5*pi  0.0  0.00
# 2      pi -1.0 -0.67
# 3  1.5*pi -0.0 -0.00
# 4    2*pi  1.0  0.67

# %% [raw]
# ?plt.axhline

# %%
# !./gitbsh >/dev/null 2>&1
