# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import mpl_toolkits.axisartist as AxisArtist
import matplotlib.ticker as ticker
import grids as g

# %%
plt.style.use('seaborn')

# %%
def abs_val_plane(a,b,single='t'):
    if single == 't':
        x = np.arange(-1,2)
        y = [a*np.abs(i)+b for i in x]
    elif single == 'f':
        if b < 0:
            b = np.abs(b)
        else:
            b = -b
        x = np.arange(b-1, b+2)
        y = [a*np.abs(i-b) for i in x]
    print(x,y)
    return x,y

# %%
x,y = abs_val_plane(-5,-6,'f')
# Out:
# [5 6 7] [-5, 0, -5]

# %%
g.simple_grid_10x10(x,y)

# %%
x,y = abs_val_plane(6,-4,'f')
# Out:
# [3 4 5] [6, 0, 6]

# %%
g.simple_grid_10x10(x,y)

# %%
# !./gitbsh >/dev/null 2>&1
